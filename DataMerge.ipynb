# %%
import os
import pandas as pd

# %%
#Winter Months
Dec = pd.read_csv('201307-201402-citibike-tripdata/2013-12 - Citi Bike trip data.csv')
Jan = pd.read_csv('201307-201402-citibike-tripdata/2014-01 - Citi Bike trip data.csv')
Feb = pd.read_csv('201307-201402-citibike-tripdata/2014-02 - Citi Bike trip data.csv')

#Summer Months
Sept = pd.read_csv('201307-201402-citibike-tripdata/2013-09 - Citi Bike trip data.csv')
Aug = pd.read_csv('201307-201402-citibike-tripdata/2013-08 - Citi Bike trip data.csv')
Jul = pd.read_csv('201307-201402-citibike-tripdata/2013-07 - Citi Bike trip data.csv')

# %%
CB201314 = pd.concat([Dec, Jan, Feb, Sept, Aug, Jul])
CB201314.to_csv('CB201314.csv', sep = ',')
CB201314
# Out:
#         tripduration            starttime             stoptime  \
# 0               1015  2013-12-01 00:00:03  2013-12-01 00:16:58
# 1                962  2013-12-01 00:00:07  2013-12-01 00:16:09
# 2                768  2013-12-01 00:00:15  2013-12-01 00:13:03
# 3                218  2013-12-01 00:00:49  2013-12-01 00:04:27
# 4                550  2013-12-01 00:01:28  2013-12-01 00:10:38
# 5                102  2013-12-01 00:01:43  2013-12-01 00:03:25
# 6                710  2013-12-01 00:02:20  2013-12-01 00:14:10
# 7                698  2013-12-01 00:02:40  2013-12-01 00:14:18
# 8               1420  2013-12-01 00:03:02  2013-12-01 00:26:42
# 9                992  2013-12-01 00:03:25  2013-12-01 00:19:57
# 10               704  2013-12-01 00:03:58  2013-12-01 00:15:42
# 11               418  2013-12-01 00:04:19  2013-12-01 00:11:17
# 12               716  2013-12-01 00:04:19  2013-12-01 00:16:15
# 13               606  2013-12-01 00:04:21  2013-12-01 00:14:27
# ...
